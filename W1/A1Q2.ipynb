# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0,10,0.01)
plt.plot(x,x**2, label = 'cube')
plt.show()

# %%
x = [10,20,30,40]
y = ['Mess','Hall Canteen','OAT','DOAA Canteen']
plt.bar(y,x)
plt.title(' Places people eat at IITK')
plt.show()
