# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('Task_Data.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        96 non-null     int64
#  1   Team      96 non-null     object
#  2   Country   96 non-null     object
#  3   NameF     96 non-null     object
#  4   NameL     96 non-null     object
#  5   Weight    91 non-null     float64
#  6   Height    96 non-null     object
#  7   DOB       90 non-null     datetime64[ns]
#  8   Hometown  96 non-null     object
#  9   Prov      96 non-null     object
#  10  Pos       96 non-null     object
#  11  Age       96 non-null     int64
#  12  HeightFt  96 non-null     float64
#  13  HtIn      96 non-null     int64
#  14  BMI       96 non-null     int64
# dtypes: datetime64[ns](1), float64(2), int64(4), object(8)
# memory usage: 11.4+ KB

# %%
df.dropna(axis=0,subset=['Weight'],inplace=True)
df
# Out:
#     ID   Team Country     NameF       NameL  Weight Height        DOB  \
# 0    1  Women  Canada    Meghan      Agosta   148.0    5'7 1987-02-12
# 1    2  Women  Canada   Rebecca    Johnston   148.0    5'9 1989-09-24
# 2    3  Women  Canada     Laura      Stacey   156.0   5'10 1994-05-05
# 3    4  Women  Canada  Jennifer   Wakefield   172.0   5'10 1989-06-15
# 4    5  Women  Canada   Jillian    Saulnier   144.0    5'5 1992-03-07
# ..  ..    ...     ...       ...         ...     ...    ...        ...
# 91  92    Men     USA      Ryan        Stoa   210.0    6'3 1987-04-13
# 92  93    Men     USA      Troy       Terry   179.0    6'0 1997-09-10
# 93  94    Men     USA      Noah       Welch   215.0    6'4 1982-08-26
# 94  95    Men     USA     James  Wisniewski   205.0    6'0 1984-02-21
# 95  96    Men     USA      Ryan    Zapolski   203.0    6'0 1986-11-11
#
#            Hometown   Prov      Pos  Age  HeightFt  HtIn  BMI
# 0           Ruthven   Ont.  Forward   35  5.583333    67   23
# ...

# %%
df['DOB'].fillna(value='na',inplace=True)

# %%
df['Pos']
# Out:
# 0     Forward
# 1     Forward
# 2     Forward
# 3     Forward
# 4     Forward
#        ...
# 91    Forward
# 92    Forward
# 93    Defence
# 94    Defence
# 95     Goalie
# Name: Pos, Length: 91, dtype: object

# %%
df1 = df.groupby('Pos')
df1.mean()
# Out:
#                 ID      Weight        Age  HeightFt       HtIn        BMI
# Pos
# Defence  50.888889  174.037037  39.444444  5.817901  69.814815  24.925926
# Forward  44.679245  172.660377  34.207547  5.779874  69.358491  25.094340
# Goalie   54.363636  175.181818  40.454545  5.886364  70.636364  24.545455

# %%
df.groupby('Team').mean()['Weight']['Women']
# Out:
# 151.38095238095238

# %%
df.groupby('Team').median()['HtIn']['Men']
# Out:
# 72.0

# %%
df2 = df[df['Country']=='Canada'][df['Team']=='Men']
# Out:
# C:\Users\Prajjwal Kumar\AppData\Local\Temp\ipykernel_36704\3393964996.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df[df['Country']=='Canada'][df['Team']=='Men']

# %%
df2
# Out:
#     ID Team Country       NameF        NameL  Weight Height  \
# 23  24  Men  Canada     Gilbert        Brulé   190.0   5'11
# 24  25  Men  Canada      Wojtek       Wolski   220.0    6'3
# 25  26  Men  Canada       Derek          Roy   187.0    5'9
# 26  27  Men  Canada       Chris        Kelly   194.0    6'0
# 27  28  Men  Canada         Rob  Klinkhammer   214.0    6'3
# 28  29  Men  Canada     Brandon        Kozun   170.0    5'8
# 29  30  Men  Canada     Quinton       Howden   190.0    6'2
# 30  31  Men  Canada        René      Bourque   216.0    6'2
# 31  32  Men  Canada      Andrew       Ebbett   176.0    5'9
# 32  33  Men  Canada       Mason      Raymond   179.0    6'1
# 33  34  Men  Canada        Eric       O’Dell   201.0    6'1
# 34  35  Men  Canada       Maxim     Lapierre   216.0    6'0
# 35  36  Men  Canada      Linden          Vey   190.0    6'0
# 36  37  Men  Canada   Christian       Thomas   174.0    5'9
# 37  38  Men  Canada        Karl     Stollery   181.0   5'11
# ...

# %%
df3 = df[df['Country']=='USA'][df['Team']=='Women']
# Out:
# C:\Users\Prajjwal Kumar\AppData\Local\Temp\ipykernel_36704\1912939659.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df3 = df[df['Country']=='USA'][df['Team']=='Women']

# %%
df3
# Out:
#     ID   Team Country     NameF               NameL  Weight Height  \
# 48  49  Women     USA     Cayla              Barnes   145.0    5'1
# 49  50  Women     USA     Kacey             Bellamy   145.0    5'7
# 50  51  Women     USA    Hannah              Brandt   150.0    5'6
# 52  53  Women     USA   Kendall               Coyne   123.0    5'2
# 53  54  Women     USA   Brianna              Decker   150.0    5'4
# 55  56  Women     USA      Kali            Flanagan   142.0    5'4
# 56  57  Women     USA    Nicole             Hensley   155.0    5'7
# 57  58  Women     USA     Megan              Keller   160.0   5'11
# 58  59  Women     USA    Amanda              Kessel   136.0    5'5
# 59  60  Women     USA    Hilary              Knight   175.0   5'11
# 60  61  Women     USA  Jocelyne  Lamoureux-Davidson   150.0    5'6
# 61  62  Women     USA   Monique   Lamoureux-Morando   147.0    5'6
# 62  63  Women     USA      Gigi              Marvin   159.0    5'8
# ...

# %%
df4 = pd.concat([df2,df3])

# %%
df4
# Out:
#     ID   Team Country       NameF               NameL  Weight Height  \
# 23  24    Men  Canada     Gilbert               Brulé   190.0   5'11
# 24  25    Men  Canada      Wojtek              Wolski   220.0    6'3
# 25  26    Men  Canada       Derek                 Roy   187.0    5'9
# 26  27    Men  Canada       Chris               Kelly   194.0    6'0
# 27  28    Men  Canada         Rob         Klinkhammer   214.0    6'3
# 28  29    Men  Canada     Brandon               Kozun   170.0    5'8
# 29  30    Men  Canada     Quinton              Howden   190.0    6'2
# 30  31    Men  Canada        René             Bourque   216.0    6'2
# 31  32    Men  Canada      Andrew              Ebbett   176.0    5'9
# 32  33    Men  Canada       Mason             Raymond   179.0    6'1
# 33  34    Men  Canada        Eric              O’Dell   201.0    6'1
# 34  35    Men  Canada       Maxim            Lapierre   216.0    6'0
# 35  36    Men  Canada      Linden                 Vey   190.0    6'0
# ...

# %%
pd.pivot_table(df,index=["Team","Age"],aggfunc=[np.mean,len])
# Out:
#                 mean                                             len          \
#                  BMI  HeightFt       HtIn         ID      Weight BMI Country
# Team  Age
# Men   24   24.000000  6.000000  72.000000  93.000000  179.000000   1       1
#       25   26.500000  6.291667  75.500000  78.000000  215.000000   2       2
#       26   26.000000  6.083333  73.000000  78.000000  196.000000   1       1
#       30   25.333333  5.972222  71.666667  34.333333  184.666667   3       3
#       31   25.500000  6.083333  73.000000  64.000000  193.000000   2       2
#       32   26.250000  6.000000  72.000000  38.250000  194.000000   4       4
#       33   26.000000  5.875000  70.500000  73.000000  182.500000   2       2
#       34   25.200000  5.866667  70.400000  78.000000  178.600000   5       5
#       35   26.000000  6.066667  72.800000  57.600000  195.500000  10      10
#       36   26.000000  5.916667  71.000000  57.166667  186.500000   6       6
# ...
